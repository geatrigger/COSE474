# %%
# !apt update
#!apt upgrade -y
# !uname -m && cat /etc/*release
# !gcc --version
# !uname -r
# Out:
# Get:1 http://security.ubuntu.com/ubuntu bionic-security InRelease [88.7 kB]
# Ign:2 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  InRelease
# Get:3 https://cloud.r-project.org/bin/linux/ubuntu bionic-cran40/ InRelease [3,626 B]
# Ign:4 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  InRelease
# Hit:5 http://archive.ubuntu.com/ubuntu bionic InRelease
# Get:6 http://ppa.launchpad.net/c2d4u.team/c2d4u4.0+/ubuntu bionic InRelease [15.9 kB]
# Get:7 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release [697 B]
# Hit:8 https://developer.download.nvidia.com/compute/machine-learning/repos/ubuntu1804/x86_64  Release
# Get:9 https://developer.download.nvidia.com/compute/cuda/repos/ubuntu1804/x86_64  Release.gpg [836 B]
# Get:10 http://archive.ubuntu.com/ubuntu bionic-updates InRelease [88.7 kB]
# Get:11 http://security.ubuntu.com/ubuntu bionic-security/universe amd64 Packages [1,365 kB]
# ...

# %%
# !nvidia-smi
# Out:
# Sun Nov  8 05:53:44 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 455.32.00    Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   42C    P8     9W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !apt install libopencv-dev python-opencv ffmpeg
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# ffmpeg is already the newest version (7:3.4.8-0ubuntu0.2).
# libopencv-dev is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# python-opencv is already the newest version (3.2.0+dfsg-4ubuntu0.1).
# 0 upgraded, 0 newly installed, 0 to remove and 49 not upgraded.

# %%
# !sed -i 's/OPENCV=0/OPENCV=1/g' Makefile
# !sed -i 's/GPU=0/GPU=1/g' Makefile
# !sed -i 's/CUDNN_HALF=0/CUDNN_HALF=1/g' Makefile
# !sed -i 's/CUDNN=0/CUDNN=1/g' Makefile

# !cat Makefile
# !make
# Out:
# GPU=1
# CUDNN=1
# CUDNN_HALF=1
# OPENCV=1
# AVX=0
# OPENMP=0
# LIBSO=0
# ZED_CAMERA=0
# ZED_CAMERA_v2_8=0
#
# # set GPU=1 and CUDNN=1 to speedup on GPU
# # set CUDNN_HALF=1 to further speedup 3 x times (Mixed-precision on Tensor Cores) GPU: Volta, Xavier, Turing and higher
# # set AVX=1 and OPENMP=1 to speedup on CPU (if error occurs then set AVX=0)
# # set ZED_CAMERA=1 to enable ZED SDK 3.0 and above
# # set ZED_CAMERA_v2_8=1 to enable ZED SDK 2.X
#
# USE_CPP=0
# DEBUG=0
#
# ARCH= -gencode arch=compute_30,code=sm_30 \
#       -gencode arch=compute_35,code=sm_35 \
#       -gencode arch=compute_50,code=[sm_50,compute_50] \
#       -gencode arch=compute_52,code=[sm_52,compute_52] \
# 	    -gencode arch=compute_61,code=[sm_61,compute_61]
#
# OS := $(shell uname)
#
# # Tesla A100 (GA100), DGX-A100, RTX 3080
# # ARCH= -gencode arch=compute_80,code=[sm_80,compute_80]
#
# # Tesla V100
# # ARCH= -gencode arch=compute_70,code=[sm_70,compute_70]
#
# ...

# %%
# %cd /content/drive/My Drive/Colab Notebooks/darknet-master
# !make
# !chmod +x ./darknet
# Out:
# /content/drive/My Drive/Colab Notebooks/darknet-master
# chmod +x *.sh

# %%
# !./darknet partial cfg/csdarknet53-omega.cfg data/csdarknet53-omega_final.weights csdarknet53-omega.conv.105 105

# %%
# !./darknet detector train data/obj.data cfg/yolov4.cfg backup/yolov4_last.weights -dont_show
# Out:
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 139 Avg (IOU: 0.827362, GIOU: 0.826694), Class: 0.894553, Obj: 0.423094, No Obj: 0.000104, .5R: 1.000000, .75R: 1.000000, count: 3, class_loss = 0.346241, iou_loss = 8.646172, total_loss = 8.992412
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 150 Avg (IOU: 0.829116, GIOU: 0.825626), Class: 0.937538, Obj: 0.396513, No Obj: 0.001399, .5R: 1.000000, .75R: 0.944444, count: 18, class_loss = 2.740685, iou_loss = 11.242783, total_loss = 13.983468
# v3 (iou loss, Normalizer: (iou: 0.07, cls: 1.00) Region 161 Avg (IOU: 0.811895, GIOU: 0.800351), Class: 0.930409, Obj: 0.585435, No Obj: 0.007602, .5R: 0.947368, .75R: 0.789474, count: 19, class_loss = 2.005636, iou_loss = 1.905710, total_loss = 3.911345
#  total_bbox = 1279275, rewritten_bbox = 0.798734 %
# ...

# %%
# %cd /content/darknet/backup
# !cp yolov4_1000.weights /content/drive/My\ Drive/Colab\ Notebooks
# !cp yolov4_last.weights /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# /content/darknet/backup

# %%
# %cd /content/darknet/cfg
# !cp yolo-voc.cfg /content/drive/My\ Drive/Colab\ Notebooks
# Out:
# /content/darknet/cfg

# %%
# %cd /content/darknet
# !./darknet detector map cfg/voc.data cfg/yolov4.cfg backup/yolov4_1000.weights
# Out:
# [Errno 2] No such file or directory: '/content/darknet'
# /content
# /bin/bash: ./darknet: No such file or directory

# %%
# 재작업할 시 
# %cd /content/drive/My Drive/Colab Notebooks
# !cp yolov4_last.weights /content
# !cp yolo-voc.cfg /content
#darknet/cfg/voc.data path 변경해야함
#yolov4.cfg
# Out:
# /content/drive/My Drive/Colab Notebooks

# %%
# %cd /content/darknet
# !./darknet detector train cfg/voc.data cfg/yolov4.cfg /content/yolov4_last.weights -dont_show

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션

# %% [markdown]
# # 새 섹션
